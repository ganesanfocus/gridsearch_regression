# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400     False        True
# 1   18  33.770         1   1725.55230      True       False
# 2   28  33.000         3   4449.46200      True       False
# 3   33  22.705         0  21984.47061      True       False
# 4   32  28.880         0   3866.85520      True       False

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset['charges']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import GridSearchCV
# creating the parameter grid


param_grid={'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
                                        'max_features': ['auto', 'sqrt', 'log2'],
                                        'n_estimators': [2, 5, 10, 100],
                                        }



grid  = GridSearchCV(RandomForestRegressor(), param_grid=param_grid, refit=True, verbose=3, n_jobs=-1)
# fitting the model for gid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 80 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 37 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 43 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.73276202 0.78073764
#  0.79678586 0.81529759 0.74082137 0.78799368 0.79407041 0.8144821
#         nan        nan        nan        nan 0.68539814 0.77391275
#  0.7998171  0.81760467 0.72633165 0.77276197 0.7972375  0.81577658
#         nan        nan        nan        nan 0.71347211 0.77645335
#  0.79295218 0.81697069 0.73738896 0.78159625 0.79990135 0.81356957
#         nan        nan        nan        nan 0.72746033 0.77683693
#  0.79649652 0.81596712 0.72684901 0.76511326 0.79526739 0.81709921]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [2, 5, 10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
# print(grid.best_params_)
re = grid.cv_results_
print(re)

grid_predictions = grid.predict(X_test)

# print report
from sklearn.metrics import r2_score
r2_score=r2_score(y_test, grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_), r2_score)
# Out:
# {'mean_fit_time': array([7.03287125e-04, 1.10273361e-03, 8.95452499e-04, 6.02769852e-04,
#        8.33854675e-03, 1.67804241e-02, 3.17873478e-02, 3.00867224e-01,
#        8.84256363e-03, 1.90418243e-02, 3.63656998e-02, 3.49324083e-01,
#        8.02373886e-04, 1.10635757e-03, 9.07373428e-04, 7.03811646e-04,
#        9.23180580e-03, 2.02944756e-02, 3.16366196e-02, 3.29913950e-01,
#        7.73320198e-03, 2.07925320e-02, 3.17995548e-02, 3.04100180e-01,
#        6.01482391e-04, 8.03232193e-04, 7.02762604e-04, 7.11393356e-04,
#        2.19207287e-02, 5.69392204e-02, 1.31736040e-01, 6.88754845e-01,
#        2.93523788e-02, 6.64425850e-02, 9.08763885e-02, 6.63284969e-01,
#        7.72094727e-04, 1.00812912e-03, 4.00066376e-04, 5.03778458e-04,
#        7.87081718e-03, 2.01222897e-02, 4.58779812e-02, 3.77998447e-01,
#        8.70809555e-03, 1.84032917e-02, 3.81526470e-02, 3.35216856e-01]), 'std_fit_time': array([0.00040082, 0.00020657, 0.00049048, 0.00049223, 0.00068677,
#        0.00075588, 0.00154021, 0.00666817, 0.00143735, 0.0040107 ,
#        0.00557704, 0.0718666 , 0.0004012 , 0.00066821, 0.00049653,
#        0.00060336, 0.00100529, 0.00744588, 0.00170979, 0.03474244,
#        0.00154821, 0.00666895, 0.00265768, 0.00690107, 0.00049111,
#        0.00024217, 0.00040048, 0.00050935, 0.00288879, 0.01226415,
#        0.01230689, 0.19738653, 0.0094929 , 0.01822406, 0.00430542,
#        0.19573457, 0.00050302, 0.00055364, 0.00048998, 0.00044992,
#        0.00095488, 0.00463117, 0.00548999, 0.03911041, 0.00078131,
#        0.0012534 , 0.00306179, 0.02939631]), 'mean_score_time': array([0.        , 0.        , 0.        , 0.        , 0.00241623,
#        0.00211048, 0.00301032, 0.01226363, 0.00220971, 0.00211339,
#        0.00286441, 0.0131557 , 0.        , 0.        , 0.        ,
#        0.        , 0.00210667, 0.0018877 , 0.00230908, 0.01215177,
#        0.00180979, 0.00221   , 0.0042141 , 0.01217303, 0.        ,
#        0.        , 0.        , 0.        , 0.00164094, 0.00200596,
#        0.00300694, 0.00827131, 0.00170579, 0.00281091, 0.00251184,
#        0.00638666, 0.        , 0.        , 0.        , 0.        ,
#        0.00301633, 0.00200777, 0.00273752, 0.01230345, 0.00150456,
#        0.00201058, 0.00250444, 0.01060038]), 'std_score_time': array([0.        , 0.        , 0.        , 0.        , 0.00059328,
#        0.00048452, 0.00063822, 0.00059685, 0.00067989, 0.00019991,
#        0.00068381, 0.00107811, 0.        , 0.        , 0.        ,
#        0.        , 0.00066599, 0.00019115, 0.0006069 , 0.00128447,
#        0.00040232, 0.00024969, 0.00255605, 0.00114993, 0.        ,
#        0.        , 0.        , 0.        , 0.00019129, 0.0005543 ,
#        0.00031612, 0.00201388, 0.00039828, 0.00140227, 0.00070972,
#        0.00029265, 0.        , 0.        , 0.        , 0.        ,
#        0.00233552, 0.0004505 , 0.00054719, 0.00153709, 0.00044736,
#        0.00044911, 0.00063673, 0.00089615]), 'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                    'squared_error', 'squared_error', 'squared_error',
#                    'squared_error', 'squared_error', 'squared_error',
#                    'squared_error', 'squared_error', 'squared_error',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                    'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                    'poisson', 'poisson'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=['auto', 'auto', 'auto', 'auto', 'sqrt', 'sqrt', 'sqrt',
#                    'sqrt', 'log2', 'log2', 'log2', 'log2', 'auto', 'auto',
#                    'auto', 'auto', 'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2',
#                    'log2', 'log2', 'log2', 'auto', 'auto', 'auto', 'auto',
#                    'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2', 'log2', 'log2',
#                    'log2', 'auto', 'auto', 'auto', 'auto', 'sqrt', 'sqrt',
#                    'sqrt', 'sqrt', 'log2', 'log2', 'log2', 'log2'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[2, 5, 10, 100, 2, 5, 10, 100, 2, 5, 10, 100, 2, 5, 10,
#                    100, 2, 5, 10, 100, 2, 5, 10, 100, 2, 5, 10, 100, 2, 5,
#                    10, 100, 2, 5, 10, 100, 2, 5, 10, 100, 2, 5, 10, 100,
#                    2, 5, 10, 100],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value=999999), 'params': [{'criterion': 'squared_error', 'max_features': 'auto', 'n_estimators': 2}, {'criterion': 'squared_error', 'max_features': 'auto', 'n_estimators': 5}, {'criterion': 'squared_error', 'max_features': 'auto', 'n_estimators': 10}, {'criterion': 'squared_error', 'max_features': 'auto', 'n_estimators': 100}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 2}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 5}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 2}, {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 5}, {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}, {'criterion': 'friedman_mse', 'max_features': 'auto', 'n_estimators': 2}, {'criterion': 'friedman_mse', 'max_features': 'auto', 'n_estimators': 5}, {'criterion': 'friedman_mse', 'max_features': 'auto', 'n_estimators': 10}, {'criterion': 'friedman_mse', 'max_features': 'auto', 'n_estimators': 100}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 2}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 5}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 2}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 5}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}, {'criterion': 'absolute_error', 'max_features': 'auto', 'n_estimators': 2}, {'criterion': 'absolute_error', 'max_features': 'auto', 'n_estimators': 5}, {'criterion': 'absolute_error', 'max_features': 'auto', 'n_estimators': 10}, {'criterion': 'absolute_error', 'max_features': 'auto', 'n_estimators': 100}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 2}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 5}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 2}, {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 5}, {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}, {'criterion': 'poisson', 'max_features': 'auto', 'n_estimators': 2}, {'criterion': 'poisson', 'max_features': 'auto', 'n_estimators': 5}, {'criterion': 'poisson', 'max_features': 'auto', 'n_estimators': 10}, {'criterion': 'poisson', 'max_features': 'auto', 'n_estimators': 100}, {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 2}, {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 5}, {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 2}, {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 5}, {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}], 'split0_test_score': array([       nan,        nan,        nan,        nan, 0.79048329,
#        0.82254211, 0.83915021, 0.84697477, 0.79549033, 0.81378611,
#        0.81919471, 0.85037778,        nan,        nan,        nan,
#               nan, 0.56258592, 0.81108024, 0.8243422 , 0.84911458,
#        0.78260033, 0.80336501, 0.83400095, 0.84780611,        nan,
#               nan,        nan,        nan, 0.72416786, 0.82712438,
#        0.82915492, 0.85420645, 0.78809785, 0.81718198, 0.8445165 ,
#        0.84835637,        nan,        nan,        nan,        nan,
#        0.76356276, 0.80391786, 0.81180744, 0.83997239, 0.7587924 ,
#        0.8181051 , 0.81094002, 0.84284683]), 'split1_test_score': array([       nan,        nan,        nan,        nan, 0.70102872,
#        0.75894266, 0.80154173, 0.82207778, 0.73219941, 0.80112929,
#        0.79759577, 0.82344493,        nan,        nan,        nan,
#               nan, 0.76608506, 0.76521155, 0.80340753, 0.82245318,
#        0.7369265 , 0.80410028, 0.79901553, 0.82840854,        nan,
#               nan,        nan,        nan, 0.7068863 , 0.79348084,
#        0.79294241, 0.8204884 , 0.73452369, 0.79228765, 0.79714848,
#        0.82147681,        nan,        nan,        nan,        nan,
#        0.73211241, 0.79414871, 0.79864705, 0.82267078, 0.69247321,
#        0.785623  , 0.81348866, 0.82678814]), 'split2_test_score': array([       nan,        nan,        nan,        nan, 0.69315434,
#        0.78131002, 0.75395421, 0.80470387, 0.73326167, 0.75339772,
#        0.77508016, 0.79949846,        nan,        nan,        nan,
#               nan, 0.67132177, 0.76036999, 0.79202278, 0.8006925 ,
#        0.7464095 , 0.75042663, 0.79844907, 0.79992562,        nan,
#               nan,        nan,        nan, 0.69556491, 0.73888381,
#        0.77245131, 0.80626068, 0.7306282 , 0.76206453, 0.78699407,
#        0.80137562,        nan,        nan,        nan,        nan,
#        0.67314071, 0.73886565, 0.79419886, 0.80723138, 0.69608035,
#        0.72557358, 0.78295442, 0.80313872]), 'split3_test_score': array([       nan,        nan,        nan,        nan, 0.73286639,
#        0.81304921, 0.82663718, 0.83702183, 0.75897604, 0.83352017,
#        0.82071598, 0.83288961,        nan,        nan,        nan,
#               nan, 0.73107935, 0.80259187, 0.83400766, 0.84009851,
#        0.74192302, 0.77250528, 0.81673898, 0.83276586,        nan,
#               nan,        nan,        nan, 0.77047859, 0.79583142,
#        0.82238356, 0.83374436, 0.71667456, 0.79480634, 0.82166958,
#        0.82901037,        nan,        nan,        nan,        nan,
#        0.75770328, 0.80813684, 0.82133947, 0.83437302, 0.77513691,
#        0.76419016, 0.8270165 , 0.83865464]), 'split4_test_score': array([       nan,        nan,        nan,        nan, 0.74627738,
#        0.72784418, 0.76264598, 0.76570969, 0.68417942, 0.73813511,
#        0.75776543, 0.76619972,        nan,        nan,        nan,
#               nan, 0.6959186 , 0.73031011, 0.74530536, 0.77566457,
#        0.62379891, 0.73341263, 0.73798296, 0.76997679,        nan,
#               nan,        nan,        nan, 0.67026287, 0.72694631,
#        0.7478287 , 0.77015355, 0.7170205 , 0.74164074, 0.74917812,
#        0.7676287 ,        nan,        nan,        nan,        nan,
#        0.71078247, 0.7391156 , 0.75648975, 0.77558806, 0.71176216,
#        0.73207444, 0.74193735, 0.77406774]), 'mean_test_score': array([       nan,        nan,        nan,        nan, 0.73276202,
#        0.78073764, 0.79678586, 0.81529759, 0.74082137, 0.78799368,
#        0.79407041, 0.8144821 ,        nan,        nan,        nan,
#               nan, 0.68539814, 0.77391275, 0.7998171 , 0.81760467,
#        0.72633165, 0.77276197, 0.7972375 , 0.81577658,        nan,
#               nan,        nan,        nan, 0.71347211, 0.77645335,
#        0.79295218, 0.81697069, 0.73738896, 0.78159625, 0.79990135,
#        0.81356957,        nan,        nan,        nan,        nan,
#        0.72746033, 0.77683693, 0.79649652, 0.81596712, 0.72684901,
#        0.76511326, 0.79526739, 0.81709921]), 'std_test_score': array([       nan,        nan,        nan,        nan, 0.03490041,
#        0.03482734, 0.03378917, 0.02860959, 0.03649133, 0.03631312,
#        0.02462652, 0.02920057,        nan,        nan,        nan,
#               nan, 0.06926589, 0.02954394, 0.03103433, 0.02671085,
#        0.05373563, 0.02816359, 0.03239626, 0.02765128,        nan,
#               nan,        nan,        nan, 0.03345211, 0.03767072,
#        0.03044095, 0.0282375 , 0.02634111, 0.02658228, 0.03228433,
#        0.02746023,        nan,        nan,        nan,        nan,
#        0.03307094, 0.03123292, 0.02219028, 0.02309438, 0.03378793,
#        0.03430623, 0.03026997, 0.02556581]), 'rank_test_score': array([33, 33, 33, 33, 27, 19, 12,  6, 25, 17, 15,  7, 33, 33, 33, 33, 32,
#        22, 10,  1, 30, 23, 11,  5, 33, 33, 33, 33, 31, 21, 16,  3, 26, 18,
#         9,  8, 33, 33, 33, 33, 28, 20, 13,  4, 29, 24, 14,  2])}
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}: 0.8936182410593928

# %%
table = pd.DataFrame.from_dict(re)

# %%
table.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.000703      0.000401         0.000000        0.000000
# 1       0.001103      0.000207         0.000000        0.000000
# 2       0.000895      0.000490         0.000000        0.000000
# 3       0.000603      0.000492         0.000000        0.000000
# 4       0.008339      0.000687         0.002416        0.000593
#
#   param_criterion param_max_features  param_n_estimators  \
# 0   squared_error               auto                   2
# 1   squared_error               auto                   5
# 2   squared_error               auto                  10
# 3   squared_error               auto                 100
# 4   squared_error               sqrt                   2
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'max_features':...                NaN
# 1  {'criterion': 'squared_error', 'max_features':...                NaN
# 2  {'criterion': 'squared_error', 'max_features':...                NaN
# 3  {'criterion': 'squared_error', 'max_features':...                NaN
# 4  {'criterion': 'squared_error', 'max_features':...           0.790483
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4           0.701029           0.693154           0.732866           0.746277
#
#    mean_test_score  std_test_score  rank_test_score
# 0              NaN             NaN               33
# 1              NaN             NaN               33
# 2              NaN             NaN               33
# 3              NaN             NaN               33
# 4         0.732762          0.0349               27

# %%
table.to_csv('gridsearch_randomr_forest_result.csv', index=False)

# %%
age_input = float(input("Age: "))
bmi_input = float(input("BMI: "))
children_input = float(input("Children:"))
sex_male_input = int(input("Sex Male 0 or 1:"))
smoker_yes_input = int(input("Smoker Yes 0 or  1:"))

# %%
Future_Prediction=grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]]) # change the parameters according to your need
print("The future prediction for the charges is: ", Future_Prediction)
# Out:
# The future prediction for the charges is:  [15776.9229366]
