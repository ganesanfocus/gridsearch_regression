# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400     False        True
# 1   18  33.770         1   1725.55230      True       False
# 2   28  33.000         3   4449.46200      True       False
# 3   33  22.705         0  21984.47061      True       False
# 4   32  28.880         0   3866.85520      True       False

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset['charges']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import GridSearchCV
# creating the parameter grid

# criterion{“squared_error”, “absolute_error”, “friedman_mse”, “poisson”}, default=”squared_error”
# max_features{“sqrt”, “log2”, None},
param_grid={'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
                                        'max_features': ['sqrt', 'log2'],
                                        'n_estimators': [10, 100],
                                        }



grid  = GridSearchCV(RandomForestRegressor(), param_grid=param_grid, refit=True, verbose=3, n_jobs=-1)
# fitting the model for gid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
# print(grid.best_params_)
re = grid.cv_results_
print(re)

grid_predictions = grid.predict(X_test)

# print report
from sklearn.metrics import r2_score
r2_score=r2_score(y_test, grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_), r2_score)
# Out:
# {'mean_fit_time': array([0.04173112, 0.32798524, 0.03101726, 0.29855323, 0.03269935,
#        0.3358943 , 0.02847195, 0.34364033, 0.10906425, 0.95596576,
#        0.10936399, 0.98837748, 0.0523891 , 0.35485983, 0.03882756,
#        0.26067553]), 'std_fit_time': array([0.00734116, 0.02065213, 0.00308247, 0.01770908, 0.00387096,
#        0.04179012, 0.00093898, 0.04835424, 0.02224307, 0.044615  ,
#        0.02749932, 0.06150867, 0.01210361, 0.0310445 , 0.00569663,
#        0.00512946]), 'mean_score_time': array([0.00331435, 0.01228991, 0.00250783, 0.01202731, 0.00211406,
#        0.01555858, 0.00241351, 0.01147928, 0.00361762, 0.01261406,
#        0.00351295, 0.01029744, 0.00472422, 0.01339412, 0.00200377,
#        0.00732017]), 'std_score_time': array([0.00040336, 0.00102294, 0.00063734, 0.00155835, 0.0009741 ,
#        0.00499989, 0.00038262, 0.00171529, 0.00247071, 0.00470623,
#        0.00215619, 0.00131307, 0.00337379, 0.00404714, 0.00031584,
#        0.00086658]), 'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                    'squared_error', 'friedman_mse', 'friedman_mse',
#                    'friedman_mse', 'friedman_mse', 'absolute_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'poisson', 'poisson', 'poisson', 'poisson'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=['sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'log2',
#                    'log2', 'sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt',
#                    'log2', 'log2'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[10, 100, 10, 100, 10, 100, 10, 100, 10, 100, 10, 100,
#                    10, 100, 10, 100],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value=999999), 'params': [{'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}, {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}], 'split0_test_score': array([0.82680692, 0.85232163, 0.82393325, 0.84745026, 0.82342035,
#        0.84690647, 0.84098888, 0.84920704, 0.83977597, 0.8468748 ,
#        0.84335967, 0.84787747, 0.85093118, 0.84819748, 0.83257353,
#        0.84457614]), 'split1_test_score': array([0.80491488, 0.8218638 , 0.79921034, 0.82026675, 0.79380863,
#        0.82509371, 0.802875  , 0.82732814, 0.80290504, 0.82388344,
#        0.80783754, 0.82111174, 0.81018455, 0.8262716 , 0.81668374,
#        0.82264871]), 'split2_test_score': array([0.77540687, 0.80163396, 0.77819856, 0.80588312, 0.80040434,
#        0.80617668, 0.79060935, 0.8060736 , 0.797478  , 0.80727988,
#        0.79200054, 0.80887286, 0.79802621, 0.79752009, 0.76101088,
#        0.80036754]), 'split3_test_score': array([0.81622197, 0.83605325, 0.82079283, 0.83363237, 0.81532964,
#        0.83290439, 0.81835844, 0.83656146, 0.80889733, 0.83104212,
#        0.81250046, 0.82891776, 0.8158934 , 0.83838113, 0.8112285 ,
#        0.83284117]), 'split4_test_score': array([0.75625041, 0.77216862, 0.74672979, 0.77130993, 0.76287209,
#        0.77165164, 0.7671895 , 0.77031709, 0.75413654, 0.76914501,
#        0.76527068, 0.76856977, 0.75806539, 0.76546726, 0.75439125,
#        0.77454148]), 'mean_test_score': array([0.79592021, 0.81680825, 0.79377296, 0.81570849, 0.79916701,
#        0.81654658, 0.80400423, 0.81789747, 0.80063858, 0.81564505,
#        0.80419378, 0.81506992, 0.80662014, 0.81516751, 0.79517758,
#        0.81499501]), 'std_test_score': array([0.02623564, 0.02785708, 0.02872248, 0.02614327, 0.02096196,
#        0.02602093, 0.02493965, 0.02764513, 0.02748639, 0.0265046 ,
#        0.02561222, 0.02647742, 0.02997861, 0.03011544, 0.03146265,
#        0.02491007]), 'rank_test_score': array([14,  2, 16,  4, 13,  3, 11,  1, 12,  5, 10,  7,  9,  6, 15,  8])}
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}: 0.8955669358581748

# %%
table = pd.DataFrame.from_dict(re)

# %%
table.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.041731      0.007341         0.003314        0.000403
# 1       0.327985      0.020652         0.012290        0.001023
# 2       0.031017      0.003082         0.002508        0.000637
# 3       0.298553      0.017709         0.012027        0.001558
# 4       0.032699      0.003871         0.002114        0.000974
#
#   param_criterion param_max_features  param_n_estimators  \
# 0   squared_error               sqrt                  10
# 1   squared_error               sqrt                 100
# 2   squared_error               log2                  10
# 3   squared_error               log2                 100
# 4    friedman_mse               sqrt                  10
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'max_features':...           0.826807
# 1  {'criterion': 'squared_error', 'max_features':...           0.852322
# 2  {'criterion': 'squared_error', 'max_features':...           0.823933
# 3  {'criterion': 'squared_error', 'max_features':...           0.847450
# 4  {'criterion': 'friedman_mse', 'max_features': ...           0.823420
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.804915           0.775407           0.816222           0.756250
# 1           0.821864           0.801634           0.836053           0.772169
# 2           0.799210           0.778199           0.820793           0.746730
# 3           0.820267           0.805883           0.833632           0.771310
# 4           0.793809           0.800404           0.815330           0.762872
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.795920        0.026236               14
# 1         0.816808        0.027857                2
# 2         0.793773        0.028722               16
# 3         0.815708        0.026143                4
# 4         0.799167        0.020962               13

# %%
table.to_csv('gridsearch_randomr_forest_result.csv', index=False)

# %%
age_input = float(input("Age: "))
bmi_input = float(input("BMI: "))
children_input = float(input("Children:"))
sex_male_input = int(input("Sex Male 0 or 1:"))
smoker_yes_input = int(input("Smoker Yes 0 or  1:"))

# %%
Future_Prediction=grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]]) # change the parameters according to your need
print("The future prediction for the charges is: ", Future_Prediction)
# Out:
# The future prediction for the charges is:  [14333.2481488]
